# %% [markdown]
# 程式4-6

# %%
import numpy as np
from tensorflow.keras.applications import resnet50
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.resnet50 import \
    decode_predictions
import matplotlib.pyplot as plt
import tensorflow as tf
import logging
tf.get_logger().setLevel(logging.ERROR)

# %% [markdown]
# 程式4-7

# %%
#載入影像並轉換為 4D 陣列
image = load_img('data/cat.jpg', target_size=(224, 224))
image_np = img_to_array(image)
image_np = np.expand_dims(image_np, axis=0)

# %%
image_np
# Out:
# array([[[[ 26.,  14.,  26.],
#          [ 24.,  12.,  24.],
#          [ 24.,  12.,  24.],
#          ...,
#          [150., 126.,  88.],
#          [149., 125.,  87.],
#          [149., 125.,  87.]],
#
#         [[ 32.,  15.,  21.],
#          [ 29.,  12.,  18.],
#          [ 27.,  10.,  16.],
#          ...,
#          [148., 124.,  86.],
#          [148., 124.,  86.],
#          [147., 123.,  85.]],
#
#         [[ 31.,  21.,  29.],
#          [ 27.,  20.,  27.],
#          [ 23.,  16.,  23.],
#          ...,
#          [148., 124.,  86.],
#          [147., 123.,  85.],
#          [146., 122.,  84.]],
#
#         ...,
#
#         [[144.,  96.,  84.],
#          [142.,  94.,  82.],
#          [141.,  93.,  81.],
#          ...,
#          [ 76.,  23.,  31.],
#          [ 78.,  25.,  33.],
#          [ 78.,  25.,  33.]],
#
#         [[143.,  95.,  83.],
#          [143.,  95.,  83.],
#          [143.,  95.,  83.],
#          ...,
#          [ 73.,  22.,  31.],
#          [ 76.,  25.,  34.],
#          [ 75.,  24.,  33.]],
#
#         [[141.,  95.,  82.],
#          [143.,  95.,  83.],
#          [144.,  96.,  84.],
#          ...,
#          [ 71.,  21.,  30.],
#          [ 73.,  23.,  32.],
#          [ 72.,  22.,  31.]]]], dtype=float32)

# %% [markdown]
# 程式4-8

# %%
# 載入預訓練好的模型
#model = resnet50.ResNet50(weights='imagenet')
# 將輸入資料做標準化
X = resnet50.preprocess_input(image_np.copy())
# 進行預測
y = model.predict(X)
predicted_labels = decode_predictions(y)
print('predictions = ', predicted_labels)

# 顯示預測結果
plt.imshow(np.uint8(image_np[0]))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# predictions =  [[('n02123045', 'tabby', 0.17037007), ('n02124075', 'Egyptian_cat', 0.109073766), ('n02870880', 'bookcase', 0.102578044), ('n03793489', 'mouse', 0.076645255), ('n03085013', 'computer_keyboard', 0.061616015)]]
